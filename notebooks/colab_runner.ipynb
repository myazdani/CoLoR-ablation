# %% [markdown]
# # CoLoR Filter Ablation Runner
#
# Thin Colab wrapper. Keep experiment logic in repository scripts.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone <YOUR_GITHUB_REMOTE_FOR_THIS_REPO> /content/color-filter-ablation
# !git clone https://github.com/davidbrandfonbrener/color-filter-olmo.git /content/color-filter-olmo
# %cd /content/color-filter-ablation
# !pip install -r requirements.txt

# %% [markdown]
# Follow `docs/HF_GPU_RUNBOOK.md` before running the scoring cells.
